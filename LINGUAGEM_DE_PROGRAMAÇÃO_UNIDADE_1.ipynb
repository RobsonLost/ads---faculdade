# %% [markdown]
# <a href="https://colab.research.google.com/github/RobsonLost/ads---faculdade/blob/main/LINGUAGEM_DE_PROGRAMA%C3%87%C3%83O_UNIDADE_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #U1_A1

# %%
#nosso primeiro programa

print("Hello Word")
# Out:
# Hello Word

# %%
#2. Criando variaveis de tipos diferentes
x = 10
nome = "Robson"
nota = 9.50
fez_inscricao = True

# %%
print(x)
print(nome)
print(nota)
print(fez_inscricao)
# Out:
# 10
# Robson
# 9.5
# True

# %%
print(type(x))
print(type(nome))
print(type(nota))
print(type(fez_inscricao))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
nome = input("Digite seu nome ")
# Out:
# Digite seu nome Robson

# %%
print(f"Óla {nome}, bem vindo ao curso de programação")
# Out:
# Óla Robson, bem vindo ao curso de programação

# %%
Nota_1 = int(input("DIGITA A NOTA: "))
Nota_2 = int(input("DIGITA A NOTA: "))
Nota_3 = int(input("DIGITA A NOTA: "))
Nota_4 = int(input("DIGITA A NOTA: "))
# Out:
# DIGITA A NOTA: 5
# DIGITA A NOTA: 7
# DIGITA A NOTA: 8
# DIGITA A NOTA: 9

# %%
media = (Nota_1 + Nota_2 + Nota_3 + Nota_4) / 4

# %%
print(media)
# Out:
# 7.25

# %%
if media >= 6:
    situacao = "aprovado"
else:
    situacao = "reprovado"

# %%
print(situacao)
# Out:
# aprovado

# %% [markdown]
# #U1_A2

# %%
print(7>5)
# Out:
# True

# %%
print(5>7)
# Out:
# False

# %%
print(7==7)
# Out:
# True

# %%
#guardando informações
idade = 18
e_maior_de_idade = idade >= 18
print(e_maior_de_idade)
# Out:
# True

# %%
idade = int(input("DIGITA SUA IDADE: "))
if idade < 18:
  print("menor de idade")
elif idade >= 18 and idade < 60:
  print("adulto")
else:
  print("idoso")
# Out:
# DIGITA SUA IDADE: 67
# idoso

# %%
#Bem-vindo à Máquina de Vendas Automatica de ingressos de Cinema!
# Solicita a idade do cliente e quantidade de ingressos
idade = int(input("Digite sua idade: "))
# Verifica a idade para sugestão de filmes
if idade < 12:
  print("Recomendamos o filme infantil FILME 1.")
elif 12 <= idade < 18:
  print("Recomendamos o filme infantil FILME 2.")
else:
  print("Recomendamos o filme adulto FILME 3.")

#Solicitar a quantidade de ingressos
quantidade_ingressos =int(input("Digita a quantidade de ingressos que deseja: "))
#Verifica a disponibilidade de ingressos
quantidade_igressos = 10
if quantidade_ingressos > 0:
  print("ingressos estão disponíveis. Divirta-se no cinema!")
else:
  print("Desculpa, todos os ingressos estão esgotados para hoje.")
# Out:
# Digite sua idade: 12
# Recomendamos o filme infantil FILME 2.
# Digita a quantidade de ingressos que deseja: 3
# ingressos estão disponíveis. Divirta-se no cinema!

# %% [markdown]
# #U1_A3
